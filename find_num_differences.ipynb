# %%
def find_num_difference(seq1: str, seq2: str):
    differences = 0
    #go through sequences
    for i in range(len(seq1)):
        #add to differences if characters in a given indice do not match
        if seq1[i] != seq2[i]:
            differences += 1
    return differences

seq_a = "..."
seq_b = "..."

find_num_difference(seq_a, seq_b)
# Out:
# 464
